# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
# ...

# %%
df=pd.read_csv('accidents_2012_to_2014.csv')
# Out:
# C:\Users\payal\AppData\Local\Temp\ipykernel_13488\403444732.py:1: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('accidents_2012_to_2014.csv')

# %%
df.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201201BS70001                 527200                  178760  -0.169101
# 1  201201BS70002                 524930                  181430  -0.200838
# 2  201201BS70003                 525860                  178080  -0.188636
# 3  201201BS70004                 524980                  181030  -0.200259
# 4  201201BS70005                 526170                  179200  -0.183773
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.493429             1                  3                   2
# 1  51.517931             1                  3                   2
# 2  51.487618             1                  3                   2
# 3  51.514325             1                  3                   1
# 4  51.497614             1                  3                   1
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  19/01/2012  ...
# ...

# %%
df.head(100)
# Out:
#    Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0   201201BS70001                 527200                  178760  -0.169101
# 1   201201BS70002                 524930                  181430  -0.200838
# 2   201201BS70003                 525860                  178080  -0.188636
# 3   201201BS70004                 524980                  181030  -0.200259
# 4   201201BS70005                 526170                  179200  -0.183773
# ..            ...                    ...                     ...        ...
# 95  201201BS70106                 525650                  178860  -0.191381
# 96  201201BS70107                 527620                  179510  -0.162784
# 97  201201BS70108                 524400                  181090  -0.208593
# 98  201201BS70109                 526020                  178870  -0.186051
# 99  201201BS70111                 526020                  177520  -0.186532
#
# ...

# %%
df.tail()
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 464692       2.01E+12                 310037                  597647
# 464693       2.01E+12                 321509                  574063
# 464694       2.01E+12                 321337                  566365
# 464695       2.01E+12                 323869                  566853
# 464696       2.01E+12                 314072                  579971
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 464692  -3.417278  55.264773            98                  2
# 464693  -3.230255  55.054855            98                  3
# 464694  -3.230826  54.985668            98                  3
# 464695  -3.191397  54.990446            98                  2
# 464696  -3.348426  55.106700            98                  3
#
#         Number_of_Vehicles  Number_of_Casualties        Date  ...  \
# 464692                   2                     1  07/12/2014  ...
# ...

# %%
df.shape
# Out:
# (464697, 33)

# %%
df.shape[0]
# Out:
# 464697

# %%
df.shape[1]
# Out:
# 33

# %%
print("the row dataset is: ",df.shape[0])
# Out:
# the row dataset is:  464697

# %%
pr
